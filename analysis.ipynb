# %%
import pandas as pd

df = pd.read_csv(r"IncomeData.csv")
primaryData = [
    "REF_DATE",
    "Field of study",
    "Educational qualification",
    "VALUE",
    "Graduate statistics",
    "Age group",
]
df_cleaned = df[primaryData]

df_cleaned = df_cleaned[df_cleaned["Graduate statistics"].str.contains("Median employment income", na=False)]
df_cleaned
# Out:
#      REF_DATE                                     Field of study  \
# 1        2018                              Total, field of study
# 2        2018                              Total, field of study
# 4        2018                                      Education [1]
# 5        2018                                      Education [1]
# 7        2018  Visual and performing arts, and communications...
# ..        ...                                                ...
# 191      2018  Agriculture, natural resources and conservatio...
# 193      2018                     Health and related fields [10]
# 194      2018                     Health and related fields [10]
# 196      2018                  Other instructional programs [12]
# 197      2018                  Other instructional programs [12]
#
#                              Educational qualification    VALUE  \
# 1    Career, technical or professional training cer...  36300.0
# ...
